# %%
import random

# %%
random_variable = random.randint(1,5) # You can specify the start and stop range.

# %%
random_variable
# Out:
# 2

# %%
random_variable2 = random.random() # gives one random value between 0 and 1

# %%
random_variable2
# Out:
# 0.1130772029171454

# %%
random_3 = random.randrange(1,78,4) # randrange(start, stop, step)

# %%
random_3
# Out:
# 13

# %%
lst = [1,3,5,78]
random4 = random.choice(lst)

# %%
random4
# Out:
# 5

# %%
r5 = random.shuffle(lst)
r5

# %%
print(r5)
# Out:
# None

# %%
lst
# Out:
# [3, 78, 1, 5]

# %%
r6 = random.choices(lst,weights=[10,1,1,1], k=22) # Returns a list with k elemenets with weighted probabilities

# %%
r6
# Out:
# [3, 3, 3, 1, 1, 3, 3, 3, 5, 3, 3, 3, 3, 3, 3, 1, 3, 3, 5, 3, 3, 3]

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/groy/Code/Python Fundamentals'

# %%
for index, value in enumerate(lst):
    print(index, value)
# Out:
# 0 3
# 1 78
# 2 1
# 3 5

# %%
lst
# Out:
# [3, 78, 1, 5]

# %%
0x10a3064d0
# Out:
# 4465910992

# %%
print(os.cpu_count())
# Out:
# 8

# %%
pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import re

# %%
txt = 'I have many apples and oranges, but no no non nono no no watermelons'
re.findall("no", txt)
# Out:
# ['no', 'no', 'no', 'no', 'no', 'no', 'no']

# %%
os.listdir
# Out:
# <function posix.listdir(path=None)>

# %%
os.getcwd()
# Out:
# '/Users/groy/Code/Python Fundamentals'

# %%
os.path.exists("new.txt")
# Out:
# False

# %%
os.remove('new.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 os.remove('new.txt')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'new.txt'

# %%
with open("example.txt",'a') as file:
    file.write("This is the first line.\n")
    file.write("SECOND line")

# %%
with open("example.txt") as f:
    for x in f:
        print(x.strip())
# Out:
# This is the first line.SECOND lineThis is the first line.
# SECOND line
